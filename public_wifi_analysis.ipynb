# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("public-wifi.csv")

# %%
df.head()
# Out:
#            x          y  object_id                             global_id  \
# 0 -80.006667  40.456544         22  6adecc06-b03e-4d52-ae47-4557b39331de
# 1 -80.027710  40.407046         23  28feaf52-49f3-4c12-aaed-c42fc1f1cfc3
# 2 -80.021397  40.394401         24  5e382f99-c41b-4837-aaad-b79cd4340a2b
# 3 -79.987547  40.397006         25  665e443b-3348-4d93-8a42-0bf860ee61f0
# 4 -79.926537  40.460938         27  f01d16aa-3717-4f3c-bf6a-81b507c167e6
#
#                                    location_name             location_details  \
# 0     Carnegie Library of Pittsburgh - Allegheny  In building and on sidewalk
# 1     Carnegie Library of Pittsburgh - Beechview  In building and on sidewalk
# 2     Carnegie Library of Pittsburgh - Brookline  In building and on sidewalk
# 3       Carnegie Library of Pittsburgh - Carrick  In building and on sidewalk
# 4  Carnegie Library of Pittsburgh - East Liberty  In building and on sidewalk
#
# ...

# %%
df['ssid'].unique()
# Out:
# array(['CLP-Allegheny', 'CLP-Beechview', 'CLP-Brookline', 'CLP-Carrick',
#        'CLP-East Liberty', 'CLP-Hazelwood', 'CLP-Hill District',
#        'CLP-Homewood', 'CLP-Knoxville', 'CLP-Lawrenceville', 'CLP-LBPH',
#        'CLP-Main', 'CLP-Sheraden', 'CLP-South Side', 'CLP-Squirrel Hill',
#        'CLP-West End', 'CLP-Woods Run', 'Harrison Library',
#        'AC Free Library', 'Andrew Bayne Library', 'Bethel Park Library',
#        'Braddock Library', 'Brentwood Library', 'Bridgeville Library',
#        'Clairton Library', 'Cooper-Siegel Library', 'Coraopolis Library',
#        'Crafton Library', 'Dormont Library', 'Duquesne Library',
#        'Forest Hills Library', 'Greentree Library', 'Hampton Library',
#        'Homestead Public Library', 'Lincoln Park Library',
#        'Mckeesport Library', 'Avalon Library',
#        'Millvale Library Public wifi', 'MPLibrary Wireless',
#        'Mt Lebanon Library', 'CC Mellor Library', 'Northland Public WiFi',
# ...
